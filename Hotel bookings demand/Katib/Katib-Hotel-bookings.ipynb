# %%
TF_EXPERIMENT_FILE = "katibhotel.yaml"

# %% [markdown]
# **Create Experiments**

# %%
import re

from IPython.utils.capture import CapturedIO


def get_resource(captured_io: CapturedIO) -> str:
    """
    Gets a resource name from `kubectl apply -f <configuration.yaml>`.

    :param str captured_io: Output captured by using `%%capture` cell magic
    :return: Name of the Kubernetes resource
    :rtype: str
    :raises Exception: if the resource could not be created
    """
    out = captured_io.stdout
    matches = re.search(r"^(.+)\s+created", out)
    if matches is not None:
        return matches.group(1)
    else:
        raise Exception(f"Cannot get resource as its creation failed: {out}. It may already exist.")

# %% [markdown]
# **For the experiment, we want to focus on the learning rate, batch-size and optimizer. The following YAML file describes an Experiment object:**

# %%
# %%writefile $TF_EXPERIMENT_FILE
# apiVersion: "kubeflow.org/v1beta1"
# kind: Experiment
# metadata:
#   namespace: sooter
#   name: hotelbook
# spec:
#   parallelTrialCount: 3
#   maxTrialCount: 30
#   maxFailedTrialCount: 3
#   objective:
#     type: maximize
#     goal: 0.99
#     objectiveMetricName: accuracy
#   algorithm:
#     algorithmName: bayesianoptimization
#   metricsCollectorSpec:
#     kind: StdOut
#   parameters:
#     - name: learning_rate
#       parameterType: double
#       feasibleSpace:
#         min: "0.001"
#         max: "0.01"
#     - name: batch_size
#       parameterType: int
#       feasibleSpace:
#         min: "80"
#         max: "200"
#     - name: optimizer
#       parameterType: categorical
#       feasibleSpace:
#         list:
#           - adam
#           - sgd
#   trialTemplate:
#     primaryContainerName: tensorflow
#     trialParameters:
#       - name: learningRate
#         description: Learning rate for the training model
#         reference: learning_rate
#       - name: batchSize
#         description: Batch Size
#         reference: batch_size
#       - name: optimizer
#         description: Training model optimizer (sdg, adam)
#         reference: optimizer
#     trialSpec:
#       apiVersion: "kubeflow.org/v1"
#       kind: TFJob
#       spec:
#         tfReplicaSpecs:
#           Worker:
#             replicas: 1
#             restartPolicy: OnFailure
#             template:
#               metadata:
#                 annotations:
#                   sidecar.istio.io/inject: "false"
#               spec:
#                 containers:
#                   - name: tensorflow
#                     image: mavencodev/tf_hotel:v.0.2
#                     command:
#                       - "python"
#                       - "/tfjob-hotel-demand.py"
#                       - "--batch_size=${trialParameters.batchSize}"
#                       - "--learning_rate=${trialParameters.learningRate}"
#                       - "--optimizer=${trialParameters.optimizer}"
# Out:
# Writing katibhotel.yaml

# %% [markdown]
# **Run and Monitor Experiments**

# %% [markdown]
# To submit our experiment, we execute:

# %%
# %%capture kubectl_output --no-stderr
! kubectl apply -f $TF_EXPERIMENT_FILE

# %% [markdown]
# **The cell magic grabs the output of the kubectl command and stores it in an object named kubectl_output. From there we can use the utility function we defined earlier:**

# %%
EXPERIMENT = get_resource(kubectl_output)

# %% [markdown]
# **To see the status, we can then run:**

# %%
! kubectl describe $EXPERIMENT
# Out:
# Name:         hotelbook
# Namespace:    sooter
# Labels:       <none>
# Annotations:  <none>
# API Version:  kubeflow.org/v1beta1
# Kind:         Experiment
# Metadata:
#   Creation Timestamp:  2021-07-19T20:20:44Z
#   Finalizers:
#     update-prometheus-metrics
#   Generation:  1
#   Managed Fields:
#     API Version:  kubeflow.org/v1beta1
#     Fields Type:  FieldsV1
#     fieldsV1:
#       f:metadata:
#         f:annotations:
#           .:
#           f:kubectl.kubernetes.io/last-applied-configuration:
#       f:spec:
#         .:
#         f:algorithm:
#           .:
#           f:algorithmName:
#         f:maxFailedTrialCount:
#         f:maxTrialCount:
#         f:metricsCollectorSpec:
#           .:
#           f:kind:
#         f:objective:
#           .:
#           f:goal:
#           f:objectiveMetricName:
#           f:type:
#         f:parallelTrialCount:
#         f:parameters:
#         f:trialTemplate:
#           .:
#           f:primaryContainerName:
#           f:trialParameters:
#           f:trialSpec:
#             .:
#             f:apiVersion:
#             f:kind:
#             f:spec:
#               .:
#               f:tfReplicaSpecs:
#                 .:
#                 f:Worker:
#                   .:
#                   f:replicas:
#                   f:restartPolicy:
#                   f:template:
#                     .:
#                     f:metadata:
#                       .:
#                       f:annotations:
#                         .:
#                         f:sidecar.istio.io/inject:
#                     f:spec:
#                       .:
#                       f:containers:
#     Manager:      kubectl-client-side-apply
#     Operation:    Update
#     Time:         2021-07-19T20:20:43Z
#     API Version:  kubeflow.org/v1beta1
#     Fields Type:  FieldsV1
#     fieldsV1:
#       f:metadata:
#         f:finalizers:
#       f:status:
#         .:
#         f:conditions:
#         f:currentOptimalTrial:
#           .:
#           f:bestTrialName:
#           f:observation:
#             .:
#             f:metrics:
#           f:parameterAssignments:
#         f:runningTrialList:
#         f:startTime:
#         f:trials:
#         f:trialsRunning:
#     Manager:         katib-controller
#     Operation:       Update
#     Time:            2021-07-19T20:21:05Z
#   Resource Version:  5958667
#   Self Link:         /apis/kubeflow.org/v1beta1/namespaces/sooter/experiments/hotelbook
#   UID:               5699be54-a98b-40a9-8d2b-36b264450ef8
# Spec:
#   Algorithm:
#     Algorithm Name:        bayesianoptimization
#   Max Failed Trial Count:  3
#   Max Trial Count:         30
#   Metrics Collector Spec:
#     Collector:
#       Kind:  StdOut
#   Objective:
#     Goal:  0.99
#     Metric Strategies:
#       Name:                 accuracy
#       Value:                max
#     Objective Metric Name:  accuracy
#     Type:                   maximize
#   Parallel Trial Count:     3
#   Parameters:
#     Feasible Space:
#       Max:           0.01
#       Min:           0.001
#     Name:            learning_rate
#     Parameter Type:  double
#     Feasible Space:
#       Max:           200
#       Min:           80
#     Name:            batch_size
#     Parameter Type:  int
#     Feasible Space:
#       List:
#         adam
#         sgd
#     Name:            optimizer
#     Parameter Type:  categorical
#   Resume Policy:     LongRunning
#   Trial Template:
#     Failure Condition:       status.conditions.#(type=="Failed")#|#(status=="True")#
#     Primary Container Name:  tensorflow
#     Primary Pod Labels:
#       Job - Role:       master
#     Success Condition:  status.conditions.#(type=="Succeeded")#|#(status=="True")#
#     Trial Parameters:
#       Description:  Learning rate for the training model
#       Name:         learningRate
#       Reference:    learning_rate
#       Description:  Batch Size
#       Name:         batchSize
#       Reference:    batch_size
#       Description:  Training model optimizer (sdg, adam)
#       Name:         optimizer
#       Reference:    optimizer
#     Trial Spec:
#       API Version:  kubeflow.org/v1
#       Kind:         TFJob
#       Spec:
#         Tf Replica Specs:
#           Worker:
#             Replicas:        1
#             Restart Policy:  OnFailure
#             Template:
#               Metadata:
#                 Annotations:
#                   sidecar.istio.io/inject:  false
#               Spec:
#                 Containers:
#                   Command:
#                     python
#                     /tfjob-hotel-demand.py
#                     --batch_size=${trialParameters.batchSize}
#                     --learning_rate=${trialParameters.learningRate}
#                     --optimizer=${trialParameters.optimizer}
#                   Image:  mavencodev/tf_hotel:v.0.2
#                   Name:   tensorflow
# Status:
#   Conditions:
#     Last Transition Time:  2021-07-19T20:20:44Z
#     Last Update Time:      2021-07-19T20:20:44Z
#     Message:               Experiment is created
#     Reason:                ExperimentCreated
#     Status:                True
#     Type:                  Created
#     Last Transition Time:  2021-07-19T20:21:05Z
#     Last Update Time:      2021-07-19T20:21:05Z
#     Message:               Experiment is running
#     Reason:                ExperimentRunning
#     Status:                True
#     Type:                  Running
#   Current Optimal Trial:
#     Best Trial Name:
#     Observation:
#       Metrics:              <nil>
#     Parameter Assignments:  <nil>
#   Running Trial List:
#     hotelbook-6j5l4flr
#     hotelbook-rmgpvtd9
#     hotelbook-vfqrtng7
#   Start Time:      2021-07-19T20:20:44Z
#   Trials:          3
#   Trials Running:  3
# Events:            <none>

# %% [markdown]
# **To get the list of created experiments, use the following command:**

# %%
! kubectl get experiments
# Out:
# NAME                  TYPE        STATUS   AGE
# airline1              Succeeded   True     8h
# airline2-end-to-end   Running     True     3h32m
# airline3-end-to-end   Running     True     144m
# hotelbook             Running     True     72s

# %% [markdown]
# **To get the list of created trials, use the following command:**

# %%
! kubectl get trials
# Out:
# NAME                           TYPE        STATUS   AGE
# airline1-44c7fzhg              Succeeded   True     8h
# airline1-5frqpdkw              Succeeded   True     7h46m
# airline1-5xb6npd4              Succeeded   True     7h54m
# airline1-6m5qnqrm              Succeeded   True     7h38m
# airline1-7hm5hbn7              Succeeded   True     7h30m
# airline1-7s9zjzz6              Succeeded   True     8h
# airline1-7z2ncblx              Succeeded   True     7h54m
# airline1-8d85jh8m              Succeeded   True     7h30m
# airline1-8p8dlw5j              Succeeded   True     7h55m
# airline1-8t4pzj4m              Succeeded   True     8h
# airline1-9tbrwskt              Succeeded   True     7h38m
# airline1-9v9prk2v              Succeeded   True     8h
# airline1-b2xk89bs              Succeeded   True     7h46m
# airline1-d6z989nh              Succeeded   True     8h
# airline1-dhx22qg9              Succeeded   True     8h
# airline1-h2sfsb7g              Succeeded   True     8h
# airline1-hwm2p99f              Succeeded   True     8h
# airline1-jrj6hkjt              Succeeded   True     7h36m
# airline1-l6z7nk7x              Succeeded   True     8h
# airline1-lsx8kjc5              Succeeded   True     7h44m
# airline1-m6wxp56v              Succeeded   True     8h
# airline1-mk59hdpj              Succeeded   True     8h
# airline1-n4qxr9jn              Succeeded   True     8h
# airline1-ncbmgcv9              Succeeded   True     8h
# airline1-qcxngrmm              Succeeded   True     7h32m
# airline1-tr2tdkqt              Succeeded   True     8h
# airline1-w897mhc6              Succeeded   True     8h
# airline1-wkft5bx2              Succeeded   True     8h
# airline1-x6qqdn5n              Succeeded   True     8h
# airline1-xcnqv64f              Succeeded   True     8h
# airline2-end-to-end-g2z279bk   Running     True     3h45m
# airline2-end-to-end-qst4x9cn   Running     True     3h45m
# airline3-end-to-end-2q65lwdv   Running     True     158m
# airline3-end-to-end-9p2c8r22   Running     True     158m
# hotelbook-2ljdwsxc             Succeeded   True     10m
# hotelbook-42pmndbx             Succeeded   True     11m
# hotelbook-5f8h4ncd             Succeeded   True     8m41s
# hotelbook-5pxwh7x2             Succeeded   True     10m
# hotelbook-6flt2bsg             Succeeded   True     12m
# hotelbook-6j5l4flr             Succeeded   True     14m
# hotelbook-6m6fhqx9             Succeeded   True     9m44s
# hotelbook-6s42mxqt             Succeeded   True     10m
# hotelbook-7nccbgbl             Succeeded   True     7m44s
# hotelbook-7t747l6x             Succeeded   True     10m
# hotelbook-c8bwn94n             Succeeded   True     12m
# hotelbook-c9skld2l             Succeeded   True     12m
# hotelbook-cnkdkzd2             Succeeded   True     12m
# hotelbook-dwnz6lrg             Succeeded   True     11m
# hotelbook-f97khvkn             Succeeded   True     11m
# hotelbook-gfpdkn6n             Succeeded   True     7m53s
# hotelbook-k9tjmtfq             Succeeded   True     6m54s
# hotelbook-qfd2rmnr             Succeeded   True     13m
# hotelbook-qlwls5wh             Succeeded   True     13m
# hotelbook-qrnckl8j             Succeeded   True     6m31s
# hotelbook-rhspv2qq             Succeeded   True     11m
# hotelbook-rmgpvtd9             Succeeded   True     14m
# hotelbook-rxjvprgj             Succeeded   True     9m16s
# hotelbook-sd95pr74             Succeeded   True     9m42s
# hotelbook-tcsx857d             Succeeded   True     11m
# hotelbook-vfqrtng7             Succeeded   True     14m
# hotelbook-vht6h7zd             Succeeded   True     8m20s
# hotelbook-wk85hbtq             Succeeded   True     13m
# hotelbook-x7hb5spd             Succeeded   True     10m
# hotelbook-ztmspms9             Succeeded   True     13m

# %% [markdown]
# **After the experiment is completed, use describe to get the best trial results:**

# %%
! kubectl describe $EXPERIMENT
# Out:
# Name:         hotelbook
# Namespace:    sooter
# Labels:       <none>
# Annotations:  <none>
# API Version:  kubeflow.org/v1beta1
# Kind:         Experiment
# Metadata:
#   Creation Timestamp:  2021-07-19T20:20:44Z
#   Finalizers:
#     update-prometheus-metrics
#   Generation:  1
#   Managed Fields:
#     API Version:  kubeflow.org/v1beta1
#     Fields Type:  FieldsV1
#     fieldsV1:
#       f:metadata:
#         f:annotations:
#           .:
#           f:kubectl.kubernetes.io/last-applied-configuration:
#       f:spec:
#         .:
#         f:algorithm:
#           .:
#           f:algorithmName:
#         f:maxFailedTrialCount:
#         f:maxTrialCount:
#         f:metricsCollectorSpec:
#           .:
#           f:kind:
#         f:objective:
#           .:
#           f:goal:
#           f:objectiveMetricName:
#           f:type:
#         f:parallelTrialCount:
#         f:parameters:
#         f:trialTemplate:
#           .:
#           f:primaryContainerName:
#           f:trialParameters:
#           f:trialSpec:
#             .:
#             f:apiVersion:
#             f:kind:
#             f:spec:
#               .:
#               f:tfReplicaSpecs:
#                 .:
#                 f:Worker:
#                   .:
#                   f:replicas:
#                   f:restartPolicy:
#                   f:template:
#                     .:
#                     f:metadata:
#                       .:
#                       f:annotations:
#                         .:
#                         f:sidecar.istio.io/inject:
#                     f:spec:
#                       .:
#                       f:containers:
#     Manager:      kubectl-client-side-apply
#     Operation:    Update
#     Time:         2021-07-19T20:20:43Z
#     API Version:  kubeflow.org/v1beta1
#     Fields Type:  FieldsV1
#     fieldsV1:
#       f:metadata:
#         f:finalizers:
#       f:status:
#         .:
#         f:completionTime:
#         f:conditions:
#         f:currentOptimalTrial:
#           .:
#           f:bestTrialName:
#           f:observation:
#             .:
#             f:metrics:
#           f:parameterAssignments:
#         f:startTime:
#         f:succeededTrialList:
#         f:trials:
#         f:trialsSucceeded:
#     Manager:         katib-controller
#     Operation:       Update
#     Time:            2021-07-19T20:29:48Z
#   Resource Version:  5975065
#   Self Link:         /apis/kubeflow.org/v1beta1/namespaces/sooter/experiments/hotelbook
#   UID:               5699be54-a98b-40a9-8d2b-36b264450ef8
# Spec:
#   Algorithm:
#     Algorithm Name:        bayesianoptimization
#   Max Failed Trial Count:  3
#   Max Trial Count:         30
#   Metrics Collector Spec:
#     Collector:
#       Kind:  StdOut
#   Objective:
#     Goal:  0.99
#     Metric Strategies:
#       Name:                 accuracy
#       Value:                max
#     Objective Metric Name:  accuracy
#     Type:                   maximize
#   Parallel Trial Count:     3
#   Parameters:
#     Feasible Space:
#       Max:           0.01
#       Min:           0.001
#     Name:            learning_rate
#     Parameter Type:  double
#     Feasible Space:
#       Max:           200
#       Min:           80
#     Name:            batch_size
#     Parameter Type:  int
#     Feasible Space:
#       List:
#         adam
#         sgd
#     Name:            optimizer
#     Parameter Type:  categorical
#   Resume Policy:     LongRunning
#   Trial Template:
#     Failure Condition:       status.conditions.#(type=="Failed")#|#(status=="True")#
#     Primary Container Name:  tensorflow
#     Primary Pod Labels:
#       Job - Role:       master
#     Success Condition:  status.conditions.#(type=="Succeeded")#|#(status=="True")#
#     Trial Parameters:
#       Description:  Learning rate for the training model
#       Name:         learningRate
#       Reference:    learning_rate
#       Description:  Batch Size
#       Name:         batchSize
#       Reference:    batch_size
#       Description:  Training model optimizer (sdg, adam)
#       Name:         optimizer
#       Reference:    optimizer
#     Trial Spec:
#       API Version:  kubeflow.org/v1
#       Kind:         TFJob
#       Spec:
#         Tf Replica Specs:
#           Worker:
#             Replicas:        1
#             Restart Policy:  OnFailure
#             Template:
#               Metadata:
#                 Annotations:
#                   sidecar.istio.io/inject:  false
#               Spec:
#                 Containers:
#                   Command:
#                     python
#                     /tfjob-hotel-demand.py
#                     --batch_size=${trialParameters.batchSize}
#                     --learning_rate=${trialParameters.learningRate}
#                     --optimizer=${trialParameters.optimizer}
#                   Image:  mavencodev/tf_hotel:v.0.2
#                   Name:   tensorflow
# Status:
#   Completion Time:  2021-07-19T20:29:48Z
#   Conditions:
#     Last Transition Time:  2021-07-19T20:20:44Z
#     Last Update Time:      2021-07-19T20:20:44Z
#     Message:               Experiment is created
#     Reason:                ExperimentCreated
#     Status:                True
#     Type:                  Created
#     Last Transition Time:  2021-07-19T20:29:48Z
#     Last Update Time:      2021-07-19T20:29:48Z
#     Message:               Experiment is running
#     Reason:                ExperimentRunning
#     Status:                False
#     Type:                  Running
#     Last Transition Time:  2021-07-19T20:29:48Z
#     Last Update Time:      2021-07-19T20:29:48Z
#     Message:               Experiment has succeeded because max trial count has reached
#     Reason:                ExperimentMaxTrialsReached
#     Status:                True
#     Type:                  Succeeded
#   Current Optimal Trial:
#     Best Trial Name:  hotelbook-2ljdwsxc
#     Observation:
#       Metrics:
#         Latest:  0.8988
#         Max:     0.8988
#         Min:     0.8988
#         Name:    accuracy
#     Parameter Assignments:
#       Name:    learning_rate
#       Value:   0.009983226921225594
#       Name:    batch_size
#       Value:   81
#       Name:    optimizer
#       Value:   adam
#   Start Time:  2021-07-19T20:20:44Z
#   Succeeded Trial List:
#     hotelbook-sd95pr74
#     hotelbook-k9tjmtfq
#     hotelbook-6j5l4flr
#     hotelbook-2ljdwsxc
#     hotelbook-x7hb5spd
#     hotelbook-6flt2bsg
#     hotelbook-rmgpvtd9
#     hotelbook-rxjvprgj
#     hotelbook-qrnckl8j
#     hotelbook-wk85hbtq
#     hotelbook-cnkdkzd2
#     hotelbook-vfqrtng7
#     hotelbook-qfd2rmnr
#     hotelbook-c8bwn94n
#     hotelbook-gfpdkn6n
#     hotelbook-dwnz6lrg
#     hotelbook-5pxwh7x2
#     hotelbook-6s42mxqt
#     hotelbook-5f8h4ncd
#     hotelbook-42pmndbx
#     hotelbook-c9skld2l
#     hotelbook-ztmspms9
#     hotelbook-rhspv2qq
#     hotelbook-7nccbgbl
#     hotelbook-tcsx857d
#     hotelbook-7t747l6x
#     hotelbook-6m6fhqx9
#     hotelbook-qlwls5wh
#     hotelbook-f97khvkn
#     hotelbook-vht6h7zd
#   Trials:            30
#   Trials Succeeded:  30
# Events:              <none>

# %% [markdown]
# **Delete Katib Job Runs to Free up resources**

# %%
! kubectl delete -f $TF_EXPERIMENT_FILE
# Out:
# experiment.kubeflow.org "hotelbook" deleted

# %% [markdown]
# Check to see if the check to see if the pod is still up and running
